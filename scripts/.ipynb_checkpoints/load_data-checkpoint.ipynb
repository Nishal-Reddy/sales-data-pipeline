# %%
from sqlalchemy import create_engine
import pandas as pd

# DB connection
engine = create_engine("postgresql://postgres:Nishal%4056@localhost:5433/postgres")

# Load cleaned data
df = pd.read_csv("/Users/kunta/Desktop/Data Projects/sales-data-pipeline/data/processed/cleaned_sales_data.csv")



# Load into SQL
df.to_sql("sales_data", engine, if_exists="replace", index=False)

print("Data loaded into PostgreSQL!")
